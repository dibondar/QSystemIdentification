# %% [markdown]
# # !!!!! THIS CODE DOES NOT WORK ANYMORE !!!!!

# %%
#import seaborn as sns
#sns.set()
#sns.set(font_scale=1.6) 

import matplotlib.pyplot as plt
#from bi_sys_id_my_version import *
from bi_sys_id_quantum import *

# %% [markdown]
# ## Load data

# %%
with np.load('fermi_hubbard_data.npz') as data:
    original_responses = data['original_response']
    control = data['control']
    phi = data['phi']

# %%
F = control.max()
times = np.arange(original_responses.shape[1])

# %%
reconstructed = bi_sys_id_my_version(
    original_responses, 
    alpha = int(original_responses.shape[1] / 2),
    dt = times[1] - times[0],
    v = [F],
    #rank=5
)

# %%
reconstructed.Ac.shape
# Out:
# (11, 11)

# %%
#reconstructed.Ac[:] = 0.5 * (reconstructed.Ac - reconstructed.Ac.T)

# %%
plt.cm.autumn

# %%
reconstructed_responses = get_training_responses(reconstructed, times=times, p=original_responses.shape[0], u=F)

# %%
plt.title("$y^{(N)}(t)$ Input/Original Responses")
plt.plot(original_responses.T)
plt.xlabel("Time in units of $\Delta t$")
plt.ylabel("Responses")
plt.savefig('input.pdf')
plt.show()


plt.title("Reconstructed responses")
plt.plot(reconstructed_responses.T.real)
plt.xlabel("Time in units of $\Delta t$")
plt.ylabel("Responses")
plt.savefig('reproduction.pdf')
plt.show()

# %%
plt.plot(original_responses.T, 'b')
plt.plot(original_responses.T - reconstructed_responses.T, 'r')
#plt.xlim([0, 100])
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(reconstructed_responses.T)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(original_responses.T)
plt.show()

# %%
plt.plot((original_responses - reconstructed_responses).T)
#plt.ylim([-0.45, 0.3])
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
np.abs(original_responses - reconstructed_responses).max()
# Out:
# 0.30592605648732163

# %%
plt.plot(original_responses[-1])
plt.plot(reconstructed_responses[-1])
plt.ylim([-0.01, 0.01])
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(original_responses[-1] - 0 * reconstructed_responses[-1])
#plt.ylim([-0.01, 0.01])
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(original_responses[:20].T)
plt.xlim(0, 20)
# Out:
# (0, 20)
